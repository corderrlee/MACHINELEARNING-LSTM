# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.losses import mse
from tensorflow.keras.metrics import RootMeanSquaredError, mean_squared_error
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# %%
total_seoul_data = pd.read_csv('./Total_Data_Seoul.csv', engine='python')
total_seoul_data
# Out:
#                      측정일시    SO2   CO     O3    NO2  PM10  Seoul_Temp(°C)  \
# 0     2020-01-01 01:00:00  0.002  0.5  0.011  0.024  19.0            -5.9
# 1     2020-01-01 02:00:00  0.002  0.6  0.005  0.030  19.0            -5.7
# 2     2020-01-01 03:00:00  0.002  0.6  0.002  0.033  27.0            -5.6
# 3     2020-01-01 04:00:00  0.002  0.6  0.003  0.031  20.0            -5.4
# 4     2020-01-01 05:00:00  0.002  0.7  0.003  0.031  21.0            -5.2
# ...                   ...    ...  ...    ...    ...   ...             ...
# 8778  2020-12-31 19:00:00  0.002  0.4  0.016  0.023  26.0            -7.1
# 8779  2020-12-31 20:00:00  0.002  0.4  0.014  0.026  29.0            -7.1
# 8780  2020-12-31 21:00:00  0.002  0.4  0.017  0.021  23.0            -7.2
# 8781  2020-12-31 22:00:00  0.002  0.4  0.025  0.013  28.0            -7.4
# 8782  2020-12-31 23:00:00  0.002  0.3  0.030  0.008  24.0            -7.6
#
#       Seoul_Precipitation(mm)  Seoul_Wind_Speed(m/s)  Seoul_Humidity(%)  \
# 0                       1.556                    1.7               40.0
# 1                       1.556                    0.1               42.0
# 2                       0.000                    0.0               46.0
# 3                       1.556                    0.0               50.0
# 4                       1.556                    0.0               55.0
# ...                       ...                    ...                ...
# 8778                    1.556                    2.4               58.0
# 8779                    1.556                    3.2               59.0
# 8780                    1.556                    2.7               61.0
# 8781                    1.556                    2.5               66.0
# 8782                    1.556                    2.2               65.0
#
#       Seoul_Dew_Point(°C)
# 0                   -17.3
# 1                   -16.5
# 2                   -15.4
# 3                   -14.2
# 4                   -12.8
# ...                   ...
# 8778                -13.9
# 8779                -13.7
# 8780                -13.4
# 8781                -12.6
# 8782                -13.0
#
# [8783 rows x 11 columns]

# %%
total_seoul_data = total_seoul_data.iloc[:,1:]
total_seoul_data
# Out:
#         SO2   CO     O3    NO2  PM10  Seoul_Temp(°C)  Seoul_Precipitation(mm)  \
# 0     0.002  0.5  0.011  0.024  19.0            -5.9                    1.556
# 1     0.002  0.6  0.005  0.030  19.0            -5.7                    1.556
# 2     0.002  0.6  0.002  0.033  27.0            -5.6                    0.000
# 3     0.002  0.6  0.003  0.031  20.0            -5.4                    1.556
# 4     0.002  0.7  0.003  0.031  21.0            -5.2                    1.556
# ...     ...  ...    ...    ...   ...             ...                      ...
# 8778  0.002  0.4  0.016  0.023  26.0            -7.1                    1.556
# 8779  0.002  0.4  0.014  0.026  29.0            -7.1                    1.556
# 8780  0.002  0.4  0.017  0.021  23.0            -7.2                    1.556
# 8781  0.002  0.4  0.025  0.013  28.0            -7.4                    1.556
# 8782  0.002  0.3  0.030  0.008  24.0            -7.6                    1.556
#
#       Seoul_Wind_Speed(m/s)  Seoul_Humidity(%)  Seoul_Dew_Point(°C)
# 0                       1.7               40.0                -17.3
# 1                       0.1               42.0                -16.5
# 2                       0.0               46.0                -15.4
# 3                       0.0               50.0                -14.2
# 4                       0.0               55.0                -12.8
# ...                     ...                ...                  ...
# 8778                    2.4               58.0                -13.9
# 8779                    3.2               59.0                -13.7
# 8780                    2.7               61.0                -13.4
# 8781                    2.5               66.0                -12.6
# 8782                    2.2               65.0                -13.0
#
# [8783 rows x 10 columns]

# %%
def extract_inputouput(dataframe, lookback_time=3, predict_time=1):
    
    dfx = pd.DataFrame()
    dfy = pd.DataFrame()
    
    for i in range(len(dataframe) - (lookback_time - 1 ) - (predict_time)):
        
        if i % 1000 == 0 :
            print(i)
        
        rowx = []
        for timestep in range(lookback_time):
            dfRename = dataframe.iloc[[i+timestep]]
            dfRename.index = [i]
            rowx.append(dfRename)
        rowx = pd.concat(rowx, axis=1)
        dfx = pd.concat([dfx, rowx])
        
        rowy = []
        rowy = pd.DataFrame([dataframe['PM10'][i+lookback_time]])
        dfy = pd.concat([dfy, rowy], ignore_index = True)
        
    print('X, Y 데이터 분류 완료!')
    return dfx, dfy

# %%
x, t = extract_inputouput(total_seoul_data)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# X, Y 데이터 분류 완료!

# %%
x
# Out:
#         SO2   CO     O3    NO2  PM10  Seoul_Temp(°C)  Seoul_Precipitation(mm)  \
# 0     0.002  0.5  0.011  0.024  19.0            -5.9                    1.556
# 1     0.002  0.6  0.005  0.030  19.0            -5.7                    1.556
# 2     0.002  0.6  0.002  0.033  27.0            -5.6                    0.000
# 3     0.002  0.6  0.003  0.031  20.0            -5.4                    1.556
# 4     0.002  0.7  0.003  0.031  21.0            -5.2                    1.556
# ...     ...  ...    ...    ...   ...             ...                      ...
# 8775  0.002  0.3  0.031  0.008  20.0            -5.5                    1.556
# 8776  0.002  0.3  0.029  0.010  24.0            -6.1                    1.556
# 8777  0.002  0.3  0.027  0.011  24.0            -6.7                    0.000
# 8778  0.002  0.4  0.016  0.023  26.0            -7.1                    1.556
# 8779  0.002  0.4  0.014  0.026  29.0            -7.1                    1.556
#
#       Seoul_Wind_Speed(m/s)  Seoul_Humidity(%)  Seoul_Dew_Point(°C)  ...  \
# 0                       1.7               40.0                -17.3  ...
# 1                       0.1               42.0                -16.5  ...
# 2                       0.0               46.0                -15.4  ...
# 3                       0.0               50.0                -14.2  ...
# 4                       0.0               55.0                -12.8  ...
# ...                     ...                ...                  ...  ...
# 8775                    3.5               47.0                -15.0  ...
# 8776                    1.8               50.0                -14.8  ...
# 8777                    2.5               54.0                -14.4  ...
# 8778                    2.4               58.0                -13.9  ...
# 8779                    3.2               59.0                -13.7  ...
#
#         SO2   CO     O3    NO2  PM10  Seoul_Temp(°C)  Seoul_Precipitation(mm)  \
# 0     0.002  0.6  0.002  0.033  27.0            -5.6                    0.000
# 1     0.002  0.6  0.003  0.031  20.0            -5.4                    1.556
# 2     0.002  0.7  0.003  0.031  21.0            -5.2                    1.556
# 3     0.002  0.7  0.002  0.032  23.0            -4.8                    0.000
# 4     0.002  0.7  0.002  0.032  22.0            -4.6                    1.556
# ...     ...  ...    ...    ...   ...             ...                      ...
# 8775  0.002  0.3  0.027  0.011  24.0            -6.7                    0.000
# 8776  0.002  0.4  0.016  0.023  26.0            -7.1                    1.556
# 8777  0.002  0.4  0.014  0.026  29.0            -7.1                    1.556
# 8778  0.002  0.4  0.017  0.021  23.0            -7.2                    1.556
# 8779  0.002  0.4  0.025  0.013  28.0            -7.4                    1.556
#
#       Seoul_Wind_Speed(m/s)  Seoul_Humidity(%)  Seoul_Dew_Point(°C)
# 0                       0.0               46.0                -15.4
# 1                       0.0               50.0                -14.2
# 2                       0.0               55.0                -12.8
# 3                       1.9               58.0                -11.8
# 4                       2.1               62.0                -10.7
# ...                     ...                ...                  ...
# 8775                    2.5               54.0                -14.4
# 8776                    2.4               58.0                -13.9
# 8777                    3.2               59.0                -13.7
# 8778                    2.7               61.0                -13.4
# 8779                    2.5               66.0                -12.6
#
# [8780 rows x 30 columns]

# %%
t
# Out:
#          0
# 0     20.0
# 1     21.0
# 2     23.0
# 3     22.0
# 4     21.0
# ...    ...
# 8775  26.0
# 8776  29.0
# 8777  23.0
# 8778  28.0
# 8779  24.0
#
# [8780 rows x 1 columns]

# %%
x_train, x_test, t_train, t_test = train_test_split(x, t, test_size = 0.2, shuffle=False)

print('x_train shape :', x_train.shape)
print('t_train shape :', t_train.shape)
print('x_test shape :', x_test.shape)
print('t_test shape :', t_test .shape)
# Out:
# x_train shape : (7024, 30)
# t_train shape : (7024, 1)
# x_test shape : (1756, 30)
# t_test shape : (1756, 1)

# %%
timesteps = 3
feature = 10

x_train = np.array(x_train)
x_train = x_train.reshape(x_train.shape[0], timesteps, feature)

x_test = np.array(x_test)
x_test = x_test.reshape(x_test.shape[0], timesteps, feature)

t_train = np.array(t_train)
t_test = np.array(t_test)

print('reshape 후 x_train shape : ', x_train.shape)
print('t_train shape : ', t_train.shape)
print('reshape 후 x_test shape : ', x_test.shape)
print('t_test shape : ', t_test.shape)
# Out:
# reshape 후 x_train shape :  (7024, 3, 10)
# t_train shape :  (7024, 1)
# reshape 후 x_test shape :  (1756, 3, 10)
# t_test shape :  (1756, 1)

# %%
cell_size = 128
timesteps = 3
feature = 10

#순차적 모델을 만들기 위한 Sequential()함수
model = Sequential(name = 'AirPollutin_LSTM')
#LSTM Layer
model.add(LSTM(cell_size, input_shape=(timesteps, feature), return_sequences = True))
model.add(LSTM(cell_size))
# 출력층(완전연결 계층)
model.add(Dense(1))

model.compile(loss=mse, optimizer=Adam(learning_rate = 0.001), metrics=[RootMeanSquaredError()])
model.summary()
# Out:
# 2023-06-06 15:37:22.929868: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-06-06 15:37:22.932769: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-06-06 15:37:22.934502: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Model: "AirPollutin_LSTM"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 3, 128)            71168
#
#  lstm_5 (LSTM)               (None, 128)               131584
#
#  dense_2 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 202,881
# Trainable params: 202,881
# Non-trainable params: 0
# _________________________________________________________________
# 2023-06-06 15:37:23.199308: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-06-06 15:37:23.200977: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-06-06 15:37:23.202733: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
model.fit(x_train, t_train, epochs = 50, batch_size = 32)
# Out:
# Epoch 1/50
# 2023-06-06 15:37:23.811064: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-06-06 15:37:23.813171: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-06-06 15:37:23.815458: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-06-06 15:37:24.069878: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-06-06 15:37:24.071862: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-06-06 15:37:24.073829: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-06-06 15:37:25.267506: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-06-06 15:37:25.269416: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-06-06 15:37:25.271888: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-06-06 15:37:25.520709: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-06-06 15:37:25.522733: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-06-06 15:37:25.524621: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 220/220 [==============================] - 5s 5ms/step - loss: 489.5450 - root_mean_squared_error: 22.1257
# Epoch 2/50
# 220/220 [==============================] - 1s 5ms/step - loss: 178.1206 - root_mean_squared_error: 13.3462
# Epoch 3/50
# 220/220 [==============================] - 1s 5ms/step - loss: 122.9113 - root_mean_squared_error: 11.0865
# Epoch 4/50
# 220/220 [==============================] - 1s 5ms/step - loss: 100.7608 - root_mean_squared_error: 10.0380
# Epoch 5/50
# 220/220 [==============================] - 1s 5ms/step - loss: 89.2708 - root_mean_squared_error: 9.4483
# Epoch 6/50
# 220/220 [==============================] - 1s 5ms/step - loss: 81.8611 - root_mean_squared_error: 9.0477
# Epoch 7/50
# 220/220 [==============================] - 1s 5ms/step - loss: 76.0130 - root_mean_squared_error: 8.7185
# Epoch 8/50
# 220/220 [==============================] - 1s 5ms/step - loss: 72.0804 - root_mean_squared_error: 8.4900
# Epoch 9/50
# 220/220 [==============================] - 1s 5ms/step - loss: 69.6310 - root_mean_squared_error: 8.3445
# Epoch 10/50
# 220/220 [==============================] - 1s 5ms/step - loss: 66.7270 - root_mean_squared_error: 8.1687
# Epoch 11/50
# 220/220 [==============================] - 1s 5ms/step - loss: 64.7275 - root_mean_squared_error: 8.0453
# Epoch 12/50
# 220/220 [==============================] - 1s 5ms/step - loss: 62.5404 - root_mean_squared_error: 7.9082
# Epoch 13/50
# 220/220 [==============================] - 1s 5ms/step - loss: 60.1821 - root_mean_squared_error: 7.7577
# Epoch 14/50
# 220/220 [==============================] - 1s 5ms/step - loss: 58.7948 - root_mean_squared_error: 7.6678
# Epoch 15/50
# 220/220 [==============================] - 1s 5ms/step - loss: 58.2585 - root_mean_squared_error: 7.6327
# Epoch 16/50
# 220/220 [==============================] - 1s 5ms/step - loss: 55.9076 - root_mean_squared_error: 7.4771
# Epoch 17/50
# 220/220 [==============================] - 1s 5ms/step - loss: 54.5897 - root_mean_squared_error: 7.3885
# Epoch 18/50
# 220/220 [==============================] - 1s 5ms/step - loss: 52.7513 - root_mean_squared_error: 7.2630
# Epoch 19/50
# 220/220 [==============================] - 1s 5ms/step - loss: 52.5672 - root_mean_squared_error: 7.2503
# Epoch 20/50
# 220/220 [==============================] - 1s 5ms/step - loss: 51.5028 - root_mean_squared_error: 7.1765
# Epoch 21/50
# 220/220 [==============================] - 1s 5ms/step - loss: 49.9808 - root_mean_squared_error: 7.0697
# Epoch 22/50
# 220/220 [==============================] - 1s 5ms/step - loss: 49.8438 - root_mean_squared_error: 7.0600
# Epoch 23/50
# 220/220 [==============================] - 1s 5ms/step - loss: 49.7812 - root_mean_squared_error: 7.0556
# Epoch 24/50
# 220/220 [==============================] - 1s 5ms/step - loss: 48.6327 - root_mean_squared_error: 6.9737
# Epoch 25/50
# 220/220 [==============================] - 1s 5ms/step - loss: 48.2966 - root_mean_squared_error: 6.9496
# Epoch 26/50
# 220/220 [==============================] - 1s 5ms/step - loss: 46.7208 - root_mean_squared_error: 6.8353
# Epoch 27/50
# 220/220 [==============================] - 1s 5ms/step - loss: 45.6106 - root_mean_squared_error: 6.7536
# Epoch 28/50
# 220/220 [==============================] - 1s 5ms/step - loss: 44.9601 - root_mean_squared_error: 6.7052
# Epoch 29/50
# 220/220 [==============================] - 1s 5ms/step - loss: 45.9127 - root_mean_squared_error: 6.7759
# Epoch 30/50
# 220/220 [==============================] - 1s 5ms/step - loss: 43.8244 - root_mean_squared_error: 6.6200
# Epoch 31/50
# 220/220 [==============================] - 1s 5ms/step - loss: 43.4908 - root_mean_squared_error: 6.5948
# Epoch 32/50
# 220/220 [==============================] - 1s 5ms/step - loss: 42.7871 - root_mean_squared_error: 6.5412
# Epoch 33/50
# 220/220 [==============================] - 1s 5ms/step - loss: 42.5795 - root_mean_squared_error: 6.5253
# Epoch 34/50
# 220/220 [==============================] - 1s 5ms/step - loss: 42.1887 - root_mean_squared_error: 6.4953
# Epoch 35/50
# 220/220 [==============================] - 1s 5ms/step - loss: 41.8675 - root_mean_squared_error: 6.4705
# Epoch 36/50
# 220/220 [==============================] - 1s 5ms/step - loss: 41.3768 - root_mean_squared_error: 6.4325
# Epoch 37/50
# 220/220 [==============================] - 1s 5ms/step - loss: 41.2560 - root_mean_squared_error: 6.4231
# Epoch 38/50
# 220/220 [==============================] - 1s 5ms/step - loss: 40.1903 - root_mean_squared_error: 6.3396
# Epoch 39/50
# 220/220 [==============================] - 1s 5ms/step - loss: 40.0118 - root_mean_squared_error: 6.3255
# Epoch 40/50
# 220/220 [==============================] - 1s 5ms/step - loss: 39.6145 - root_mean_squared_error: 6.2940
# Epoch 41/50
# 220/220 [==============================] - 1s 5ms/step - loss: 39.2720 - root_mean_squared_error: 6.2667
# Epoch 42/50
# 220/220 [==============================] - 1s 5ms/step - loss: 39.2974 - root_mean_squared_error: 6.2688
# Epoch 43/50
# 220/220 [==============================] - 1s 5ms/step - loss: 39.5743 - root_mean_squared_error: 6.2908
# Epoch 44/50
# 220/220 [==============================] - 1s 5ms/step - loss: 38.2876 - root_mean_squared_error: 6.1877
# Epoch 45/50
# 220/220 [==============================] - 1s 5ms/step - loss: 38.5054 - root_mean_squared_error: 6.2053
# Epoch 46/50
# 220/220 [==============================] - 1s 5ms/step - loss: 37.9244 - root_mean_squared_error: 6.1583
# Epoch 47/50
# 220/220 [==============================] - 1s 5ms/step - loss: 37.5228 - root_mean_squared_error: 6.1256
# Epoch 48/50
# 220/220 [==============================] - 1s 5ms/step - loss: 38.0864 - root_mean_squared_error: 6.1714
# Epoch 49/50
# 220/220 [==============================] - 1s 5ms/step - loss: 38.4217 - root_mean_squared_error: 6.1985
# Epoch 50/50
# 220/220 [==============================] - 1s 5ms/step - loss: 38.0326 - root_mean_squared_error: 6.1671

# %%
pred = model.predict(x_test)

for i in range(1, 10):
    print('PM10 예측 : ', round(pred[i][0], 2), '/정답: ', round(t_test[i][0], 2))
# Out:
# 2023-06-06 15:38:24.957656: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-06-06 15:38:24.959651: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-06-06 15:38:24.961228: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-06-06 15:38:25.197797: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-06-06 15:38:25.199640: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-06-06 15:38:25.201434: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 55/55 [==============================] - 1s 2ms/step
# PM10 예측 :  67.6 /정답:  75.0
# PM10 예측 :  67.47 /정답:  70.0
# PM10 예측 :  65.54 /정답:  74.0
# PM10 예측 :  69.65 /정답:  65.0
# PM10 예측 :  63.4 /정답:  59.0
# PM10 예측 :  60.54 /정답:  56.0
# PM10 예측 :  57.35 /정답:  52.0
# PM10 예측 :  51.31 /정답:  53.0
# PM10 예측 :  53.51 /정답:  51.0

# %%
#전체 test data에 대한 모델 성능 평가
loss, rmse = model.evaluate(x_test, t_test, verbose=1)
print('test loss(MSE) :', round(loss, 6))
print('test RMSE : ', round(rmse, 2))
# Out:
# 2023-06-06 15:38:25.888957: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-06-06 15:38:25.890861: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-06-06 15:38:25.892411: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-06-06 15:38:26.137389: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-06-06 15:38:26.139087: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-06-06 15:38:26.140939: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 55/55 [==============================] - 1s 2ms/step - loss: 60.7139 - root_mean_squared_error: 7.7919
# test loss(MSE) : 60.713879
# test RMSE :  7.79
